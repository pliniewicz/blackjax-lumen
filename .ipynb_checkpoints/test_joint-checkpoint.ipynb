# %%
import jax
jax.config.update("jax_enable_x64", True)
import jax.numpy as jnp
import numpy as np
import blackjax
from blackjax.ns.utils import finalise, log_weights, sample, ess
import tqdm

from lumen import (
    make_params, make_cosmology, make_log_likelihood,
    load_sed_Fnu, observed_sed, MODEL_1A, kpc,
)

# %%
cosmo = make_cosmology(71.0, 0.27, 0.73)
data_knot = load_sed_Fnu("mydata.csv", unit="mJy")
data_ext = load_sed_Fnu("mydata_ext.csv", unit="mJy")

print(f"Knot: {len(data_knot)} points, upper limits: {data_knot.has_upper_limits}")
print(f"Ext:  {len(data_ext)} points, upper limits: {data_ext.has_upper_limits}")
# Out:
# Knot: 3 points, upper limits: False
# Ext:  3 points, upper limits: True

# %%
FIXED_COMMON = dict(
    q_ratio=1.0, p=2.7,
    gamma_min=1e2, gamma_max=1e6,
    z=2.5, eta_e=0.1, model=int(MODEL_1A),
)

# %%
FIXED_KNOT = {**FIXED_COMMON, "Rj": 3 * kpc, "l": 3 * kpc}
FIXED_EXT  = {**FIXED_COMMON, "Rj": 3 * kpc, "l": 80 * kpc}

# %%
SAMPLED = {
    "G0":      (2.0,   30.0),
    "theta":   (5.0,   25.0),
    "Lj":      (1e46,  1e50),
}

# %%
param_names = list(SAMPLED.keys())
ndim = len(param_names)
lo = jnp.array([SAMPLED[k][0] for k in param_names])
hi = jnp.array([SAMPLED[k][1] for k in param_names])

# %%
def vec_to_params_knot(x):
    kw = dict(FIXED_KNOT)
    for i, name in enumerate(param_names):
        kw[name] = x[i]
    return make_params(**kw)


def vec_to_params_ext(x):
    kw = dict(FIXED_EXT)
    for i, name in enumerate(param_names):
        kw[name] = x[i]
    return make_params(**kw)

def logprior_fn(x):
    in_bounds = jnp.all((x >= lo) & (x <= hi))
    log_vol = jnp.sum(jnp.log(hi - lo))
    return jnp.where(in_bounds, -log_vol, -jnp.inf)

# %%
_loglik_knot = make_log_likelihood(data_knot, cosmo=cosmo, nx=64, ngamma=64)
_loglik_ext  = make_log_likelihood(data_ext,  cosmo=cosmo, nx=64, ngamma=64)


def loglikelihood_fn(x):
    params_knot = vec_to_params_knot(x)
    params_ext  = vec_to_params_ext(x)
    return _loglik_knot(params_knot) + _loglik_ext(params_ext)

# %%
n_live = 500
num_delete = 50
num_inner_steps = 5 * ndim

algo = blackjax.nss(
    logprior_fn=logprior_fn,
    loglikelihood_fn=loglikelihood_fn,
    num_delete=num_delete,
    num_inner_steps=num_inner_steps,
)

rng_key = jax.random.PRNGKey(42)
rng_key, init_key = jax.random.split(rng_key)
initial_population = jax.random.uniform(
    init_key, (n_live, ndim), minval=lo, maxval=hi,
)

state = algo.init(initial_population)
step = jax.jit(algo.step)

dead = []

print(f"\nRunning joint nested sampling: {ndim} dims, {n_live} live points")
with tqdm.tqdm(desc="Dead points", unit=" dead points") as pbar:
    while not state.integrator.logZ_live - state.integrator.logZ < -3:
        rng_key, subkey = jax.random.split(rng_key)
        state, dead_info = step(subkey, state)
        dead.append(dead_info)
        pbar.update(num_delete)
# Out:
# Running joint nested sampling: 3 dims, 500 live points
# Dead points: 0 dead points [00:04, ? dead points/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 27
#      25 while not state.integrator.logZ_live - state.integrator.logZ < -3:
#      26     rng_key, subkey = jax.random.split(rng_key)
# ---> 27     state, dead_info = step(subkey, state)
#      28     dead.append(dead_info)
#      29     pbar.update(num_delete)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:256, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     252   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     253                      "`jit`, but 'no_tracing' is set")
#     254 p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     255 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 256  executable, pgle_profiler, const_args) = _run_python_pjit(
#     257      p, args_flat, fun, args, kwargs)
#     259 maybe_fastpath_data = _get_fastpath_data(
#     260     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     261     pgle_profiler, const_args)
#     263 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:141, in _run_python_pjit(p, args_flat, fun, args, kwargs)
#     139   args_flat = map(core.full_lower, args_flat)
#     140   core.check_eval_args(args_flat)
# --> 141   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     142       *args_flat, **p.params)
#     143 else:
#     144   out_flat = jit_p.bind(*args_flat, **p.params)
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1217, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1206 arg_types = map(convert_to_metaty, args)
#    1207 computation = _resolve_and_lower(
#    1208     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1209     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1215     compiler_options_kvs=compiler_options_kvs,
#    1216 )
# -> 1217 compiled = computation.compile()
#    1219 # This check is expensive so only do it if enable_checks is on.
#    1220 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2516, in MeshComputation.compile(self, compiler_options, device_assignment)
#    2513 if use_cache and self._executable is not None:
#    2514   return self._executable
# -> 2516 executable = UnloadedMeshExecutable.from_hlo(
#    2517     self._name, self._hlo, **self.compile_args,
#    2518     compiler_options_kvs=compiler_options_kvs,
#    2519     device_list=compilation_device_list)
#    2520 if use_cache:
#    2521   self._executable = executable
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:3063, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    3060       break
#    3062 util.test_event("pxla_cached_compilation")
# -> 3063 xla_executable = _cached_compilation(
#    3064     hlo, name, mesh, spmd_lowering,
#    3065     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    3066     allow_prop_to_outputs, tuple(host_callbacks), backend, device_list,
#    3067     pmap_nreps, compiler_options_kvs, pgle_profiler)
#    3069 if auto_spmd_lowering:
#    3070   assert mesh is not None
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2844, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2836 compile_options = create_compile_options(
#    2837     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2838     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2839     dev, pmap_nreps, compiler_options)
#    2841 with dispatch.log_elapsed_time(
#    2842     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2843     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2844   xla_executable = compiler.compile_or_get_cached(
#    2845       backend, computation, dev, compile_options, host_callbacks,
#    2846       da, pgle_profiler)
#    2847 return xla_executable
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:478, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     476 else:
#     477   log_persistent_cache_miss(module_name, cache_key)
# --> 478   return _compile_and_write_cache(
#     479       backend,
#     480       computation,
#     481       executable_devices,
#     482       compile_options,
#     483       host_callbacks,
#     484       module_name,
#     485       cache_key,
#     486   )
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:746, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     736 def _compile_and_write_cache(
#     737     backend: xc.Client,
#     738     computation: ir.Module,
#    (...)    743     cache_key: str,
#     744 ) -> xc.LoadedExecutable:
#     745   start_time = time.monotonic()
# --> 746   executable = backend_compile_and_load(
#     747       backend, computation, executable_devices, compile_options, host_callbacks
#     748   )
#     749   compile_time = time.monotonic() - start_time
#     750   _cache_write(
#     751       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     752   )
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/profiler.py:384, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     381 @wraps(func)
#     382 def wrapper(*args, **kwargs):
#     383   with TraceAnnotation(name, **decorator_kwargs):
# --> 384     return func(*args, **kwargs)
#
# File ~/Documents/PhD/Projekty/Programy/blackjax-lumen/.venv/lib/python3.12/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
rng_key, wkey, skey = jax.random.split(rng_key, 3)
final = finalise(state, dead)
ns_ess = ess(skey, final)
log_w = log_weights(wkey, final, shape=100)
logzs = jax.scipy.special.logsumexp(log_w, axis=0)
posterior = sample(skey, final, shape=n_live)

print(f"\nlogZ = {logzs.mean():.2f} ± {logzs.std():.2f}")
print(f"ESS  = {int(ns_ess)}")
print()
for i, name in enumerate(param_names):
    vals = posterior.position[:, i]
    print(f"  {name:12s}: {vals.mean():.4g} ± {vals.std():.4g}")

# %%
import anesthetic
import matplotlib.pyplot as plt

ns_samples = anesthetic.NestedSamples(
    data=final.particles.position,
    columns=param_names,
    logL=final.particles.loglikelihood,
    logL_birth=final.particles.loglikelihood_birth,
)

prior_plot = ns_samples.set_beta(0.0).plot_2d(
    param_names, label="prior"
)
ns_samples.plot_2d(prior_plot, label="posterior")
prior_plot.iloc[-1, 0].legend(
    bbox_to_anchor=(len(prior_plot), len(prior_plot)),
    loc="lower right",
)

# %%
import matplotlib.pyplot as plt

nu_plot = jnp.array(10 ** np.arange(7, 26, 0.05))

median_vec = jnp.median(posterior.position, axis=0)
p_knot = vec_to_params_knot(median_vec)
p_ext  = vec_to_params_ext(median_vec)
flux_knot = observed_sed(nu_plot, p_knot, cosmo, nx=64, ngamma=64)
flux_ext  = observed_sed(nu_plot, p_ext,  cosmo, nx=64, ngamma=64)

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(nu_plot, flux_knot, "-",  color="C0", lw=1.5, label="knot (median)")
ax.plot(nu_plot, flux_ext,  "--", color="C1", lw=1.5, label="extended (median)")
ax.plot(nu_plot, flux_knot + flux_ext, "-", color="0.4", lw=1, alpha=0.5, label="total")

# Knot data
ax.errorbar(
    np.array(data_knot.frequencies), np.array(data_knot.fluxes),
    yerr=np.array(data_knot.errors),
    fmt="o", color="C0", ms=6, capsize=3, zorder=10, label="knot data",
)

# Extended jet data — distinguish detections from upper limits
ext_det = data_ext.detections()
ext_ul  = data_ext.upper_limits()

if len(ext_det):
    ax.errorbar(
        np.array(ext_det.frequencies), np.array(ext_det.fluxes),
        yerr=np.array(ext_det.errors),
        fmt="s", color="C1", ms=6, capsize=3, zorder=10, label="ext data",
    )
if len(ext_ul):
    ax.errorbar(
        np.array(ext_ul.frequencies), np.array(ext_ul.fluxes),
        yerr=0.3 * np.array(ext_ul.fluxes),  # arrow length
        fmt="v", color="C1", ms=6, uplims=True, zorder=10, label="ext upper limit",
    )

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel(r"$\nu$ [Hz]", fontsize=13)
ax.set_ylabel(r"$\nu F_\nu$ [erg/s/cm$^2$]", fontsize=13)
ax.set_xlim(1e7, 1e26)
ax.set_ylim(1e-20,1e-10)
ax.legend(fontsize=10)
fig.tight_layout()
# fig.savefig("ns_sed_joint.pdf", dpi=150)
# print("SED plot saved to ns_sed_joint.pdf")
